# %% [markdown]
# # File processor

# %% [markdown]
# csv_decoder.py is a packaged version of Josh's methods reading .csv generated by his c++ showering code.
# save_and_load.py specifically saves and loads all essential lists/images used in the analysis to np.save formats.
#
# This notebook shows the example use of methods in csv_decoder.py and save_and_load.py. It reads .csv files containing particle eta, phi, pt, ... produced by Josh's showering program, performs fast detector simulation to generate detector & jet images, and saves to faster np.save format. The save(), load() and load_cluster() methods are saved in

# %%
# Import local libraries
import csv_decoder
import save_and_load
import importlib
import numpy as np

# %%
# Jet and event image setting
width = 40
height = 40

# %%
# reading in event files from a given folder.
def generate_images(path, contains=".csv" ,max_read=float('inf'), max_files=float('inf'), 
                    weighted=0, pt_cut=1, width_param=width, height_param=height):
    # Reading in files
    event_list,mass_list,image_list,num_files = csv_decoder.load_events(
            path = path, 
            contains = contains, 
            max_read = max_read, 
            max_files = max_files, 
            weighted = weighted, 
            pt_cut = 1, width=width_param, height=height_param)

    # Cluster events_lists into jets. The results are named background/signal_event_list_clustered
    print('Clustering')
    event_list_clustered = csv_decoder.cluster_event(event_list)

    # Reclustering the events (i.e. clustering within events)
    print('Reclustering')
    reclustered = csv_decoder.recluster_event(event_list_clustered)

    # Produce jet images, the zero-center and normalize
    print('Producing jet images')
    recluster_images = csv_decoder.return_fine_image_list_reclustered(event_list,
                                                           reclustered,0.8, width=width, height=height)
    # Weight calculation, UNFINISHED!
    weight = -1
    
    return event_list, mass_list, weight, image_list, recluster_images

# %%
# Reading in Josh's files; background is a single large file (pT cut must be 1 here for Josh's sample)
# This read produces event_list (collection of raw vectors) and event images

# This will be used to test saving mechanisms.

print('Loading background events')
background_event_list,background_mass_list,background_image_list,num_background_files = \
    csv_decoder.load_events(path="/data1/users/jzlin/MLM/background_7413/",\
                contains="actual_actual",max_files=1,pt_cut=1, width=width, height=height)
num_background_files = 15693

print('Loading signal events')
signal_event_list,signal_mass_list,signal_image_list,num_signal_files = \
    csv_decoder.load_events(path="/data1/users/jzlin/MLM/heavy_signal/",\
                contains="actual_signal",max_read = len(background_event_list),pt_cut=1, width=width, height=height)

# TEMP: 

# Check size of dataset
print(len(background_mass_list),len(signal_mass_list))


# This is not used
background_mass_window = np.logical_and(np.array(background_mass_list) > 115,np.array(background_mass_list) < 135)

# Cluster events_lists into jets. The results are named background/signal_event_list_clustered
print('Clustering')
background_event_list_clustered = csv_decoder.cluster_event(background_event_list)
signal_event_list_clustered = csv_decoder.cluster_event(signal_event_list)

# Reclustering the events (i.e. clustering within events)
print('Reclustering')
background_reclustered = csv_decoder.recluster_event(background_event_list_clustered)
signal_reclustered = csv_decoder.recluster_event(signal_event_list_clustered)

# Produce jet images, the zero-center and normalize
print('Producing jet images')
background_recluster_images = csv_decoder.return_fine_image_list_reclustered(background_event_list,
                                                           background_reclustered,0.8, width=width, height=height)
signal_recluster_images = csv_decoder.return_fine_image_list_reclustered(signal_event_list,
                                                           signal_reclustered,0.8, width=width, height=height)

# Zero centering and normalizing
background_image_list, signal_image_list = csv_decoder.zero_center_and_normalize_pair(background_image_list,signal_image_list)
background_recluster_images, signal_recluster_images = csv_decoder.zero_center_and_normalize_pair(background_recluster_images, signal_recluster_images)

# %%
# Reading in custom showered files;
# This read produces event_list (collection of raw vectors) and event images

# This will be used to test saving mechanisms.

print('Loading hj events')
hj_event_list,hj_mass_list,hj_image_list,num_hj_files = \
    csv_decoder.load_events(path="/home/ffu/higgs-classifier/showering/ggh-hj-csv/",\
                contains=".csv",pt_cut=1, width=width, height=height)
print('Loading vh events')
vh_event_list,vh_mass_list,vh_image_list,num_vh_files = \
    csv_decoder.load_events(path="/home/ffu/higgs-classifier/showering/vh-csv",\
                contains=".csv",pt_cut=1, width=width, height=height)

# TEMP:
# Out:
# Loading hj events
# Loading .csv event files from /home/ffu/higgs-classifier/showering/ggh-hj-csv/ containing ".csv"
# List of files is: ['10821_seed_48693.csv', '8907_seed_21111.csv', '12404_seed_9250.csv', '2147_seed_102040.csv', '12510_seed_16335.csv', '32446_seed_15733.csv', 'shower.log', '8973_seed_10851.csv', '18163_seed_19884.csv', '15844_seed_11119.csv', '19998_seed_67154.csv', '11277_seed_68435.csv', '16660_seed_66561.csv', '25036_seed_34274.csv', '2131_seed_99873.csv', '27581_seed_17695.csv', '84_seed_49639.csv', '516_seed_57502.csv', '29564_seed_4680.csv', '11716_seed_9464.csv', '27173_seed_52207.csv', '30639_seed_47610.csv', '11204_seed_70732.csv', '7513_seed_101207.csv', '31789_seed_23041.csv', '26068_seed_33822.csv', '22335_seed_95781.csv', '3841_seed_47086.csv', '1715_seed_63566.csv', '11758_seed_74447.csv', '12396_seed_37982.csv', '10706_seed_36167.csv', '527_seed_77920.csv', '31653_seed_998.csv', '9295_seed_19397.csv', '13701_seed_6.csv', '20740_seed_53443.csv', '21491_seed_16184.csv', '32500_seed_50508.csv', '27338_seed_72790.csv', '17679_seed_102282.csv', '22123_seed_8121.csv', '23341_seed_12125.csv', '25731_seed_49542.csv', '26040_seed_53032.csv', '946_seed_88388.csv', '20393_seed_87730.csv', '19981_seed_51637.csv', '13584_seed_60330.csv', '23532_seed_24636.csv', '5241_seed_85655.csv']
# Currently reading: 10821_seed_48693.csv
# 10821_seed_48693.csv
# 1files processed.
# Currently reading: 8907_seed_21111.csv
# 8907_seed_21111.csv
# 2files processed.
# Currently reading: 12404_seed_9250.csv
# 12404_seed_9250.csv
# 3files processed.
# Currently reading: 2147_seed_102040.csv
# 2147_seed_102040.csv
# 4files processed.
# Currently reading: 12510_seed_16335.csv
# 12510_seed_16335.csv
# 5files processed.
# Currently reading: 32446_seed_15733.csv
# 32446_seed_15733.csv
# 6files processed.
# Currently reading: shower.log
# Currently reading: 8973_seed_10851.csv
# 8973_seed_10851.csv
# 7files processed.
# Currently reading: 18163_seed_19884.csv
# 18163_seed_19884.csv
# 8files processed.
# Currently reading: 15844_seed_11119.csv
# 15844_seed_11119.csv
# 9files processed.
# Currently reading: 19998_seed_67154.csv
# 19998_seed_67154.csv
# 10files processed.
# Currently reading: 11277_seed_68435.csv
# 11277_seed_68435.csv
# 11files processed.
# Currently reading: 16660_seed_66561.csv
# 16660_seed_66561.csv
# 12files processed.
# Currently reading: 25036_seed_34274.csv
# 25036_seed_34274.csv
# 13files processed.
# Currently reading: 2131_seed_99873.csv
# 2131_seed_99873.csv
# 14files processed.
# Currently reading: 27581_seed_17695.csv
# 27581_seed_17695.csv
# 15files processed.
# Currently reading: 84_seed_49639.csv
# 84_seed_49639.csv
# 16files processed.
# Currently reading: 516_seed_57502.csv
# 516_seed_57502.csv
# 17files processed.
# Currently reading: 29564_seed_4680.csv
# 29564_seed_4680.csv
# 18files processed.
# Currently reading: 11716_seed_9464.csv
# 11716_seed_9464.csv
# 19files processed.
# Currently reading: 27173_seed_52207.csv
# 27173_seed_52207.csv
# 20files processed.
# Currently reading: 30639_seed_47610.csv
# 30639_seed_47610.csv
# 21files processed.
# Currently reading: 11204_seed_70732.csv
# 11204_seed_70732.csv
# 22files processed.
# Currently reading: 7513_seed_101207.csv
# 7513_seed_101207.csv
# 23files processed.
# Currently reading: 31789_seed_23041.csv
# 31789_seed_23041.csv
# 24files processed.
# Currently reading: 26068_seed_33822.csv
# 26068_seed_33822.csv
# 25files processed.
# Currently reading: 22335_seed_95781.csv
# 22335_seed_95781.csv
# 26files processed.
# Currently reading: 3841_seed_47086.csv
# 3841_seed_47086.csv
# 27files processed.
# Currently reading: 1715_seed_63566.csv
# 1715_seed_63566.csv
# 28files processed.
# Currently reading: 11758_seed_74447.csv
# 11758_seed_74447.csv
# 29files processed.
# Currently reading: 12396_seed_37982.csv
# 12396_seed_37982.csv
# 30files processed.
# Currently reading: 10706_seed_36167.csv
# 10706_seed_36167.csv
# 31files processed.
# Currently reading: 527_seed_77920.csv
# 527_seed_77920.csv
# 32files processed.
# Currently reading: 31653_seed_998.csv
# 31653_seed_998.csv
# 33files processed.
# Currently reading: 9295_seed_19397.csv
# 9295_seed_19397.csv
# 34files processed.
# Currently reading: 13701_seed_6.csv
# 13701_seed_6.csv
# 35files processed.
# Currently reading: 20740_seed_53443.csv
# 20740_seed_53443.csv
# 36files processed.
# Currently reading: 21491_seed_16184.csv
# 21491_seed_16184.csv
# 37files processed.
# Currently reading: 32500_seed_50508.csv
# 32500_seed_50508.csv
# 38files processed.
# Currently reading: 27338_seed_72790.csv
# 27338_seed_72790.csv
# 39files processed.
# Currently reading: 17679_seed_102282.csv
# 17679_seed_102282.csv
# 40files processed.
# Currently reading: 22123_seed_8121.csv
# 22123_seed_8121.csv
# 41files processed.
# Currently reading: 23341_seed_12125.csv
# 23341_seed_12125.csv
# 42files processed.
# Currently reading: 25731_seed_49542.csv
# 25731_seed_49542.csv
# 43files processed.
# Currently reading: 26040_seed_53032.csv
# 26040_seed_53032.csv
# 44files processed.
# Currently reading: 946_seed_88388.csv
# 946_seed_88388.csv
# 45files processed.
# Currently reading: 20393_seed_87730.csv
# 20393_seed_87730.csv
# 46files processed.
# Currently reading: 19981_seed_51637.csv
# 19981_seed_51637.csv
# 47files processed.
# Currently reading: 13584_seed_60330.csv
# 13584_seed_60330.csv
# 48files processed.
# Currently reading: 23532_seed_24636.csv
# 23532_seed_24636.csv
# 49files processed.
# Currently reading: 5241_seed_85655.csv
# 5241_seed_85655.csv
# 50files processed.
# Loading vh events
# Loading .csv event files from /home/ffu/higgs-classifier/showering/vh-csv containing ".csv"
# List of files is: ['9039_seed_65396.csv', '4993_seed_62397.csv', '6011_seed_3726.csv', '23690_seed_4942.csv', '12001_seed_87907.csv', '2411_seed_99596.csv', '2811_seed_52913.csv', '12134_seed_14506.csv', 'shower.log', '6668_seed_82945.csv', '8428_seed_8452.csv', '16066_seed_16432.csv', '32401_seed_30146.csv', '7613_seed_12358.csv', '1033_seed_31869.csv', '8632_seed_55222.csv', '16757_seed_102773.csv', '13005_seed_27128.csv', '220_seed_78615.csv', '25330_seed_89712.csv', '19396_seed_28757.csv', '31691_seed_42095.csv', '7749_seed_88428.csv', '476_seed_68604.csv', '6619_seed_34890.csv', '31340_seed_9404.csv', '4118_seed_168.csv', '9236_seed_879.csv', '20677_seed_69889.csv', '25937_seed_9683.csv', '4223_seed_4459.csv', '29374_seed_26643.csv', '26687_seed_58211.csv', '9230_seed_53926.csv', '19995_seed_71539.csv', '32070_seed_30346.csv', '14887_seed_49876.csv', '23258_seed_40268.csv', '21187_seed_94365.csv', '18518_seed_24334.csv', '17392_seed_13254.csv', '18159_seed_46658.csv', '19264_seed_99490.csv', '27818_seed_79618.csv', '7132_seed_5844.csv', '2827_seed_23621.csv', '16753_seed_45219.csv', '3820_seed_6844.csv', '9889_seed_48301.csv', '29515_seed_66845.csv', '12813_seed_64192.csv']
# Currently reading: 9039_seed_65396.csv
# 9039_seed_65396.csv
# 1files processed.
# Currently reading: 4993_seed_62397.csv
# 4993_seed_62397.csv
# 2files processed.
# Currently reading: 6011_seed_3726.csv
# 6011_seed_3726.csv
# 3files processed.
# Currently reading: 23690_seed_4942.csv
# 23690_seed_4942.csv
# 4files processed.
# Currently reading: 12001_seed_87907.csv
# 12001_seed_87907.csv
# 5files processed.
# Currently reading: 2411_seed_99596.csv
# 2411_seed_99596.csv
# 6files processed.
# Currently reading: 2811_seed_52913.csv
# 2811_seed_52913.csv
# 7files processed.
# Currently reading: 12134_seed_14506.csv
# 12134_seed_14506.csv
# 8files processed.
# Currently reading: shower.log
# Currently reading: 6668_seed_82945.csv
# 6668_seed_82945.csv
# 9files processed.
# Currently reading: 8428_seed_8452.csv
# 8428_seed_8452.csv
# 10files processed.
# Currently reading: 16066_seed_16432.csv
# 16066_seed_16432.csv
# 11files processed.
# Currently reading: 32401_seed_30146.csv
# 32401_seed_30146.csv
# 12files processed.
# Currently reading: 7613_seed_12358.csv
# 7613_seed_12358.csv
# 13files processed.
# Currently reading: 1033_seed_31869.csv
# 1033_seed_31869.csv
# 14files processed.
# Currently reading: 8632_seed_55222.csv
# 8632_seed_55222.csv
# 15files processed.
# Currently reading: 16757_seed_102773.csv
# 16757_seed_102773.csv
# 16files processed.
# Currently reading: 13005_seed_27128.csv
# 13005_seed_27128.csv
# 17files processed.
# Currently reading: 220_seed_78615.csv
# 220_seed_78615.csv
# 18files processed.
# Currently reading: 25330_seed_89712.csv
# 25330_seed_89712.csv
# 19files processed.
# Currently reading: 19396_seed_28757.csv
# 19396_seed_28757.csv
# 20files processed.
# Currently reading: 31691_seed_42095.csv
# 31691_seed_42095.csv
# 21files processed.
# Currently reading: 7749_seed_88428.csv
# 7749_seed_88428.csv
# 22files processed.
# Currently reading: 476_seed_68604.csv
# 476_seed_68604.csv
# 23files processed.
# Currently reading: 6619_seed_34890.csv
# 6619_seed_34890.csv
# 24files processed.
# Currently reading: 31340_seed_9404.csv
# 31340_seed_9404.csv
# 25files processed.
# Currently reading: 4118_seed_168.csv
# 4118_seed_168.csv
# 26files processed.
# Currently reading: 9236_seed_879.csv
# 9236_seed_879.csv
# 27files processed.
# Currently reading: 20677_seed_69889.csv
# 20677_seed_69889.csv
# 28files processed.
# Currently reading: 25937_seed_9683.csv
# 25937_seed_9683.csv
# 29files processed.
# Currently reading: 4223_seed_4459.csv
# 4223_seed_4459.csv
# 30files processed.
# Currently reading: 29374_seed_26643.csv
# 29374_seed_26643.csv
# 31files processed.
# Currently reading: 26687_seed_58211.csv
# 26687_seed_58211.csv
# 32files processed.
# Currently reading: 9230_seed_53926.csv
# 9230_seed_53926.csv
# 33files processed.
# Currently reading: 19995_seed_71539.csv
# 19995_seed_71539.csv
# 34files processed.
# Currently reading: 32070_seed_30346.csv
# 32070_seed_30346.csv
# 35files processed.
# Currently reading: 14887_seed_49876.csv
# 14887_seed_49876.csv
# 36files processed.
# Currently reading: 23258_seed_40268.csv
# 23258_seed_40268.csv
# 37files processed.
# Currently reading: 21187_seed_94365.csv
# 21187_seed_94365.csv
# 38files processed.
# Currently reading: 18518_seed_24334.csv
# 18518_seed_24334.csv
# 39files processed.
# Currently reading: 17392_seed_13254.csv
# 17392_seed_13254.csv
# 40files processed.
# Currently reading: 18159_seed_46658.csv
# 18159_seed_46658.csv
# 41files processed.
# Currently reading: 19264_seed_99490.csv
# 19264_seed_99490.csv
# 42files processed.
# Currently reading: 27818_seed_79618.csv
# 27818_seed_79618.csv
# 43files processed.
# Currently reading: 7132_seed_5844.csv
# 7132_seed_5844.csv
# 44files processed.
# Currently reading: 2827_seed_23621.csv
# 2827_seed_23621.csv
# 45files processed.
# Currently reading: 16753_seed_45219.csv
# 16753_seed_45219.csv
# 46files processed.
# Currently reading: 3820_seed_6844.csv
# 3820_seed_6844.csv
# 47files processed.
# Currently reading: 9889_seed_48301.csv
# 9889_seed_48301.csv
# 48files processed.
# Currently reading: 29515_seed_66845.csv
# 29515_seed_66845.csv
# 49files processed.
# Currently reading: 12813_seed_64192.csv
# 12813_seed_64192.csv
# 50files processed.
# Dataset sizes:
# 74795 54242
# Clustering
# Reclustering
# Producing jet images
# Number of events with only one constituent in leading jet: 673
# Number of events with only one constituent in leading jet: 790

# %%
importlib.reload(csv_decoder)

# Check size of dataset
print("Dataset sizes:")
print(len(vh_mass_list),len(hj_mass_list))


# This is not used
vh_mass_window = np.logical_and(np.array(vh_mass_list) > 115,np.array(vh_mass_list) < 135)

# Cluster events_lists into jets. The results are named vh/hj_event_list_clustered
print('Clustering')
vh_event_list_clustered = csv_decoder.cluster_event(vh_event_list)
hj_event_list_clustered = csv_decoder.cluster_event(hj_event_list)

# Reclustering the events (i.e. clustering within events)
print('Reclustering')
vh_reclustered = csv_decoder.recluster_event(vh_event_list_clustered)
hj_reclustered = csv_decoder.recluster_event(hj_event_list_clustered)

# Produce jet images, the zero-center and normalize
print('Producing jet images')
vh_recluster_images = csv_decoder.return_fine_image_list_reclustered(vh_event_list,
                                                           vh_reclustered,0.8, width=width, height=height)
hj_recluster_images = csv_decoder.return_fine_image_list_reclustered(hj_event_list,
                                                           hj_reclustered,0.8, width=width, height=height)

# Zero centering and normalizing
vh_image_list, hj_image_list = csv_decoder.zero_center_and_normalize_pair(vh_image_list,hj_image_list)
vh_recluster_images, hj_recluster_images = csv_decoder.zero_center_and_normalize_pair(vh_recluster_images, hj_recluster_images)
# Out:
# Dataset sizes:
# 74795 54242
# Clustering
# Reclustering
# Producing jet images
# Number of events with only one constituent in leading jet: 267
# Number of events with only one constituent in leading jet: 388

# %%
# Weight calculation for Josh's sample
backgroundCross = 2.048e-06 # Cross-section of processes in millibarns, NOT USED

actual_background_cross=2.84e-9 # In barns, used in background weight
average_number_accepted=2162 # Used in background weight

actual_signal_cross = np.average([1.738e-14,1.7277e-14]) # Used in signal weight
signal_accepted = np.average([8708-189,8827-172]) # Used in signal weight 

background_weight = actual_background_cross*35.9*1e15/(average_number_accepted*num_background_files)
signal_weight = actual_signal_cross*35.9*1e15/(signal_accepted*num_signal_files)
# Weight is calculated by cross section * 35.9(integrated luminosity) * 1e15 / # total event 
# cross_sec*L_int = dN/dt

# Testing saving time for Josh's samples
# Time: 19.26s
save_and_load.save('hbb-qcd', background_event_list, signal_event_list, background_mass_list, signal_mass_list,\
        background_weight, signal_weight, background_image_list, signal_image_list,\
        background_recluster_images, signal_recluster_images)

# Testing reading for .npy files of Josh's samples
new_background_event_list, new_signal_event_list, new_background_mass_list, new_signal_mass_list,\
        new_background_weight, new_signal_weight, new_background_image_list, new_signal_image_list,\
        new_background_recluster_images, new_signal_recluster_images = save_and_load.load('hbb-qcd')
print(np.array_equal(new_background_mass_list, background_mass_list))
print(np.array_equal(new_signal_mass_list, signal_mass_list))
print(np.array_equal(new_background_weight, background_weight))
print(np.array_equal(new_signal_weight, signal_weight))
print(np.array_equal(new_background_image_list, background_image_list))
print(np.array_equal(new_signal_image_list, signal_image_list))
print(np.array_equal(new_background_recluster_images, background_recluster_images))
print(np.array_equal(new_signal_recluster_images, signal_recluster_images))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a6257de0bfc7> in <module>
#       8 signal_accepted = np.average([8708-189,8827-172]) # Used in signal weight
#       9
# ---> 10 background_weight = actual_background_cross*35.9*1e15/(average_number_accepted*num_background_files)
#      11 signal_weight = actual_signal_cross*35.9*1e15/(signal_accepted*num_signal_files)
#      12 # Weight is calculated by cross section * 35.9(integrated luminosity) * 1e15 / # total event
#
# NameError: name 'num_background_files' is not defined

# %%
# Weight calculation for custom samples
importlib.reload(save_and_load)
hj_cross=0.008e-12 # hj cross section is 0.00800 pb. This var is In barns, used in vh weight
#  === Results Summary for run: run_44 tag: tag_1 ===
#
#     Cumulative sequential time for this run: 4m31s
#     Cross-section :   0.008017 +- 4.206e-05 pb
#     Nb of events :  10000
vh_cross=1.5e-14 # vh cross section is 1.5e-2pb.
#   --------------------------------------------------------------
#      Summary:
#      Process p p > H v [QCD] @0 ; p p > H v j [QCD] @1
#      Run at p-p collider (6500.0 + 6500.0 GeV)
#      Number of events generated: 10000
#      Total cross section: 1.427e-02 +- 1.1e-04 pb
#   --------------------------------------------------------------
#      Scale variation (computed from LHE events):
#          Dynamical_scale_choice -1 (envelope of 9 values): 
#              1.493e-02 pb  +2.4% -3.4%
#   --------------------------------------------------------------


vh_weight = vh_cross*35.9*1e15/len(vh_event_list)
hj_weight = hj_cross*35.9*1e15/len(hj_event_list)
# Weight is calculated by cross section * 35.9(integrated luminosity) * 1e15 / # total event 
# cross_sec*L_int = dN/dt

# Testing saving time for Josh's samples
# Time: 19.26s
save_and_load.save_binary('vh-hj', vh_event_list, hj_event_list, vh_mass_list, hj_mass_list,\
        vh_weight, hj_weight, vh_image_list, hj_image_list,\
        vh_recluster_images, hj_recluster_images, name_1='vh', name_2='hj')

# %%
# Processing VBF and VH samples
vbf_event_list, vbf_mass_list, vbf_weight, vbf_image_list, vbf_recluster_images = generate_images(path='/home/ffu/higgs-classifier/samples/vbf-csv/')
vh_event_list, vh_mass_list, vh_weight, vh_image_list, vh_recluster_images = generate_images(path='/home/ffu/higgs-classifier/samples/vh-csv/')
# Out:
# Loading .csv event files from /home/ffu/higgs-classifier/samples/vbf-csv/ containing ".csv"
# List of files is: ['18785.csv_seed_35134.csv', '18811.csv_seed_89257.csv', '14476.csv_seed_55984.csv', '23458.csv_seed_36303.csv', '20603.csv_seed_31091.csv', '29482.csv_seed_36569.csv', '21204.csv_seed_54727.csv', '20755.csv_seed_65604.csv', '11662.csv_seed_48142.csv', '16875.csv_seed_52464.csv', '32557.csv_seed_3475.csv', '29973.csv_seed_94611.csv', '2811.csv_seed_46037.csv', 'shower.log', '25983.csv_seed_4370.csv', '11898.csv_seed_7268.csv', '1897.csv_seed_29944.csv', '21260.csv_seed_31664.csv', '19431.csv_seed_45453.csv', '9444.csv_seed_60674.csv', '7065.csv_seed_76323.csv', '12664.csv_seed_2591.csv', '942.csv_seed_25797.csv', '28338.csv_seed_91335.csv', '20731.csv_seed_68406.csv', '6579.csv_seed_63483.csv', '14591.csv_seed_590.csv', '13089.csv_seed_69302.csv', '23383.csv_seed_18721.csv', '15197.csv_seed_2718.csv', '3393.csv_seed_951.csv', '5161.csv_seed_104568.csv', '27011.csv_seed_4938.csv', '17016.csv_seed_72919.csv', '19572.csv_seed_97881.csv', '6463.csv_seed_73464.csv', '27798.csv_seed_88556.csv', '26829.csv_seed_45762.csv', '17057.csv_seed_89740.csv', '19979.csv_seed_43177.csv', '24551.csv_seed_67091.csv', '9967.csv_seed_14207.csv', '21021.csv_seed_45552.csv', '4761.csv_seed_18339.csv', '24253.csv_seed_26713.csv', '22555.csv_seed_69020.csv', '32762.csv_seed_35897.csv', '8625.csv_seed_55976.csv', '871.csv_seed_10803.csv', '4451.csv_seed_101879.csv', '3631.csv_seed_78063.csv']
# Currently reading: 18785.csv_seed_35134.csv
# 18785.csv_seed_35134.csv
# 1files processed.
# Currently reading: 18811.csv_seed_89257.csv
# 18811.csv_seed_89257.csv
# 2files processed.
# Currently reading: 14476.csv_seed_55984.csv
# 14476.csv_seed_55984.csv
# 3files processed.
# Currently reading: 23458.csv_seed_36303.csv
# 23458.csv_seed_36303.csv
# 4files processed.
# Currently reading: 20603.csv_seed_31091.csv
# 20603.csv_seed_31091.csv
# 5files processed.
# Currently reading: 29482.csv_seed_36569.csv
# 29482.csv_seed_36569.csv
# 6files processed.
# Currently reading: 21204.csv_seed_54727.csv
# 21204.csv_seed_54727.csv
# 7files processed.
# Currently reading: 20755.csv_seed_65604.csv
# 20755.csv_seed_65604.csv
# 8files processed.
# Currently reading: 11662.csv_seed_48142.csv
# 11662.csv_seed_48142.csv
# 9files processed.
# Currently reading: 16875.csv_seed_52464.csv
# 16875.csv_seed_52464.csv
# 10files processed.
# Currently reading: 32557.csv_seed_3475.csv
# 32557.csv_seed_3475.csv
# 11files processed.
# Currently reading: 29973.csv_seed_94611.csv
# 29973.csv_seed_94611.csv
# 12files processed.
# Currently reading: 2811.csv_seed_46037.csv
# 2811.csv_seed_46037.csv
# 13files processed.
# Currently reading: shower.log
# Currently reading: 25983.csv_seed_4370.csv
# 25983.csv_seed_4370.csv
# 14files processed.
# Currently reading: 11898.csv_seed_7268.csv
# 11898.csv_seed_7268.csv
# 15files processed.
# Currently reading: 1897.csv_seed_29944.csv
# 1897.csv_seed_29944.csv
# 16files processed.
# Currently reading: 21260.csv_seed_31664.csv
# 21260.csv_seed_31664.csv
# 17files processed.
# Currently reading: 19431.csv_seed_45453.csv
# 19431.csv_seed_45453.csv
# 18files processed.
# Currently reading: 9444.csv_seed_60674.csv
# 9444.csv_seed_60674.csv
# 19files processed.
# Currently reading: 7065.csv_seed_76323.csv
# 7065.csv_seed_76323.csv
# 20files processed.
# Currently reading: 12664.csv_seed_2591.csv
# 12664.csv_seed_2591.csv
# 21files processed.
# Currently reading: 942.csv_seed_25797.csv
# 942.csv_seed_25797.csv
# 22files processed.
# Currently reading: 28338.csv_seed_91335.csv
# 28338.csv_seed_91335.csv
# 23files processed.
# Currently reading: 20731.csv_seed_68406.csv
# 20731.csv_seed_68406.csv
# 24files processed.
# Currently reading: 6579.csv_seed_63483.csv
# 6579.csv_seed_63483.csv
# 25files processed.
# Currently reading: 14591.csv_seed_590.csv
# 14591.csv_seed_590.csv
# 26files processed.
# Currently reading: 13089.csv_seed_69302.csv
# 13089.csv_seed_69302.csv
# 27files processed.
# Currently reading: 23383.csv_seed_18721.csv
# 23383.csv_seed_18721.csv
# 28files processed.
# Currently reading: 15197.csv_seed_2718.csv
# 15197.csv_seed_2718.csv
# 29files processed.
# Currently reading: 3393.csv_seed_951.csv
# 3393.csv_seed_951.csv
# 30files processed.
# Currently reading: 5161.csv_seed_104568.csv
# 5161.csv_seed_104568.csv
# 31files processed.
# Currently reading: 27011.csv_seed_4938.csv
# 27011.csv_seed_4938.csv
# 32files processed.
# Currently reading: 17016.csv_seed_72919.csv
# 17016.csv_seed_72919.csv
# 33files processed.
# Currently reading: 19572.csv_seed_97881.csv
# 19572.csv_seed_97881.csv
# 34files processed.
# Currently reading: 6463.csv_seed_73464.csv
# 6463.csv_seed_73464.csv
# 35files processed.
# Currently reading: 27798.csv_seed_88556.csv
# 27798.csv_seed_88556.csv
# 36files processed.
# Currently reading: 26829.csv_seed_45762.csv
# 26829.csv_seed_45762.csv
# 37files processed.
# Currently reading: 17057.csv_seed_89740.csv
# 17057.csv_seed_89740.csv
# 38files processed.
# Currently reading: 19979.csv_seed_43177.csv
# 19979.csv_seed_43177.csv
# 39files processed.
# Currently reading: 24551.csv_seed_67091.csv
# 24551.csv_seed_67091.csv
# 40files processed.
# Currently reading: 9967.csv_seed_14207.csv
# 9967.csv_seed_14207.csv
# 41files processed.
# Currently reading: 21021.csv_seed_45552.csv
# 21021.csv_seed_45552.csv
# 42files processed.
# Currently reading: 4761.csv_seed_18339.csv
# 4761.csv_seed_18339.csv
# 43files processed.
# Currently reading: 24253.csv_seed_26713.csv
# 24253.csv_seed_26713.csv
# 44files processed.
# Currently reading: 22555.csv_seed_69020.csv
# 22555.csv_seed_69020.csv
# 45files processed.
# Currently reading: 32762.csv_seed_35897.csv
# 32762.csv_seed_35897.csv
# 46files processed.
# Currently reading: 8625.csv_seed_55976.csv
# 8625.csv_seed_55976.csv
# 47files processed.
# Currently reading: 871.csv_seed_10803.csv
# 871.csv_seed_10803.csv
# 48files processed.
# Currently reading: 4451.csv_seed_101879.csv
# 4451.csv_seed_101879.csv
# 49files processed.
# Currently reading: 3631.csv_seed_78063.csv
# 3631.csv_seed_78063.csv
# 50files processed.
# Clustering
# Reclustering
# Producing jet images
# Number of events with only one constituent in leading jet: 0
# Loading .csv event files from /home/ffu/higgs-classifier/samples/vh-csv/ containing ".csv"
# List of files is: ['1666.csv_seed_69301.csv', '30693.csv_seed_73993.csv', '3457.csv_seed_61666.csv', '18223.csv_seed_18740.csv', '26647.csv_seed_68629.csv', 'shower.log', '11122.csv_seed_72579.csv', '21413.csv_seed_30975.csv', '9753.csv_seed_16683.csv', '24538.csv_seed_14432.csv', '25533.csv_seed_36948.csv', '12547.csv_seed_68514.csv', '9616.csv_seed_88480.csv', '7462.csv_seed_81435.csv', '24404.csv_seed_35910.csv', '14145.csv_seed_58825.csv', '22005.csv_seed_51967.csv', '9799.csv_seed_96263.csv', '17667.csv_seed_25156.csv', '2390.csv_seed_48839.csv', '3657.csv_seed_36217.csv', '11574.csv_seed_51397.csv', '7217.csv_seed_92294.csv', '15121.csv_seed_9061.csv', '4175.csv_seed_97585.csv', '26487.csv_seed_63147.csv', '14695.csv_seed_57479.csv', '29691.csv_seed_3882.csv', '9266.csv_seed_64696.csv', '13512.csv_seed_2704.csv', '8363.csv_seed_62323.csv', '3053.csv_seed_17740.csv', '13404.csv_seed_59227.csv', '11885.csv_seed_43914.csv', '26881.csv_seed_32050.csv', '3862.csv_seed_14101.csv', '31058.csv_seed_23032.csv', '29817.csv_seed_68136.csv', '9445.csv_seed_86461.csv', '14083.csv_seed_19734.csv', '6273.csv_seed_51555.csv', '11772.csv_seed_91281.csv', '3943.csv_seed_59289.csv', '11194.csv_seed_99321.csv', '4065.csv_seed_25678.csv', '17422.csv_seed_57235.csv', '30289.csv_seed_44687.csv', '24843.csv_seed_51872.csv', '12287.csv_seed_29187.csv', '9699.csv_seed_7236.csv', '29721.csv_seed_28924.csv']
# Currently reading: 1666.csv_seed_69301.csv
# 1666.csv_seed_69301.csv
# 1files processed.
# Currently reading: 30693.csv_seed_73993.csv
# 30693.csv_seed_73993.csv
# 2files processed.
# Currently reading: 3457.csv_seed_61666.csv
# 3457.csv_seed_61666.csv
# 3files processed.
# Currently reading: 18223.csv_seed_18740.csv
# 18223.csv_seed_18740.csv
# 4files processed.
# Currently reading: 26647.csv_seed_68629.csv
# 26647.csv_seed_68629.csv
# 5files processed.
# Currently reading: shower.log
# Currently reading: 11122.csv_seed_72579.csv
# 11122.csv_seed_72579.csv
# 6files processed.
# Currently reading: 21413.csv_seed_30975.csv
# 21413.csv_seed_30975.csv
# 7files processed.
# Currently reading: 9753.csv_seed_16683.csv
# 9753.csv_seed_16683.csv
# 8files processed.
# Currently reading: 24538.csv_seed_14432.csv
# 24538.csv_seed_14432.csv
# 9files processed.
# Currently reading: 25533.csv_seed_36948.csv
# 25533.csv_seed_36948.csv
# 10files processed.
# Currently reading: 12547.csv_seed_68514.csv
# 12547.csv_seed_68514.csv
# 11files processed.
# Currently reading: 9616.csv_seed_88480.csv
# 9616.csv_seed_88480.csv
# 12files processed.
# Currently reading: 7462.csv_seed_81435.csv
# 7462.csv_seed_81435.csv
# 13files processed.
# Currently reading: 24404.csv_seed_35910.csv
# 24404.csv_seed_35910.csv
# 14files processed.
# Currently reading: 14145.csv_seed_58825.csv
# 14145.csv_seed_58825.csv
# 15files processed.
# Currently reading: 22005.csv_seed_51967.csv
# 22005.csv_seed_51967.csv
# 16files processed.
# Currently reading: 9799.csv_seed_96263.csv
# 9799.csv_seed_96263.csv
# 17files processed.
# Currently reading: 17667.csv_seed_25156.csv
# 17667.csv_seed_25156.csv
# 18files processed.
# Currently reading: 2390.csv_seed_48839.csv
# 2390.csv_seed_48839.csv
# 19files processed.
# Currently reading: 3657.csv_seed_36217.csv
# 3657.csv_seed_36217.csv
# 20files processed.
# Currently reading: 11574.csv_seed_51397.csv
# 11574.csv_seed_51397.csv
# 21files processed.
# Currently reading: 7217.csv_seed_92294.csv
# 7217.csv_seed_92294.csv
# 22files processed.
# Currently reading: 15121.csv_seed_9061.csv
# 15121.csv_seed_9061.csv
# 23files processed.
# Currently reading: 4175.csv_seed_97585.csv
# 4175.csv_seed_97585.csv
# 24files processed.
# Currently reading: 26487.csv_seed_63147.csv
# 26487.csv_seed_63147.csv
# 25files processed.
# Currently reading: 14695.csv_seed_57479.csv
# 14695.csv_seed_57479.csv
# 26files processed.
# Currently reading: 29691.csv_seed_3882.csv
# 29691.csv_seed_3882.csv
# 27files processed.
# Currently reading: 9266.csv_seed_64696.csv
# 9266.csv_seed_64696.csv
# 28files processed.
# Currently reading: 13512.csv_seed_2704.csv
# 13512.csv_seed_2704.csv
# 29files processed.
# Currently reading: 8363.csv_seed_62323.csv
# 8363.csv_seed_62323.csv
# 30files processed.
# Currently reading: 3053.csv_seed_17740.csv
# 3053.csv_seed_17740.csv
# 31files processed.
# Currently reading: 13404.csv_seed_59227.csv
# 13404.csv_seed_59227.csv
# 32files processed.
# Currently reading: 11885.csv_seed_43914.csv
# 11885.csv_seed_43914.csv
# 33files processed.
# Currently reading: 26881.csv_seed_32050.csv
# 26881.csv_seed_32050.csv
# 34files processed.
# Currently reading: 3862.csv_seed_14101.csv
# 3862.csv_seed_14101.csv
# 35files processed.
# Currently reading: 31058.csv_seed_23032.csv
# 31058.csv_seed_23032.csv
# 36files processed.
# Currently reading: 29817.csv_seed_68136.csv
# 29817.csv_seed_68136.csv
# 37files processed.
# Currently reading: 9445.csv_seed_86461.csv
# 9445.csv_seed_86461.csv
# 38files processed.
# Currently reading: 14083.csv_seed_19734.csv
# 14083.csv_seed_19734.csv
# 39files processed.
# Currently reading: 6273.csv_seed_51555.csv
# 6273.csv_seed_51555.csv
# 40files processed.
# Currently reading: 11772.csv_seed_91281.csv
# 11772.csv_seed_91281.csv
# 41files processed.
# Currently reading: 3943.csv_seed_59289.csv
# 3943.csv_seed_59289.csv
# 42files processed.
# Currently reading: 11194.csv_seed_99321.csv
# 11194.csv_seed_99321.csv
# 43files processed.
# Currently reading: 4065.csv_seed_25678.csv
# 4065.csv_seed_25678.csv
# 44files processed.
# Currently reading: 17422.csv_seed_57235.csv
# 17422.csv_seed_57235.csv
# 45files processed.
# Currently reading: 30289.csv_seed_44687.csv
# 30289.csv_seed_44687.csv
# 46files processed.
# Currently reading: 24843.csv_seed_51872.csv
# 24843.csv_seed_51872.csv
# 47files processed.
# Currently reading: 12287.csv_seed_29187.csv
# 12287.csv_seed_29187.csv
# 48files processed.
# Currently reading: 9699.csv_seed_7236.csv
# 9699.csv_seed_7236.csv
# 49files processed.
# Currently reading: 29721.csv_seed_28924.csv
# 29721.csv_seed_28924.csv
# 50files processed.
# Clustering
# Reclustering
# Producing jet images
# Number of events with only one constituent in leading jet: 0

# %%
# Zero-centering and normalizing
#vbf_image_list, vh_image_list = csv_decoder.zero_center_and_normalize_pair(vbf_image_list, vh_image_list)
(vbf_image_list, vh_image_list) = csv_decoder.zero_center_and_normalize((vbf_image_list, vh_image_list))
print(len(vbf_event_list))
print(len(vh_event_list))
# Out:
# 393
# 1209
